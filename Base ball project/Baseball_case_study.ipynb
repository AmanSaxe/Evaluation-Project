# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('baseball.csv')

# %%
data
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
data.shape
# Out:
# (30, 17)

# %%
data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# ##### Checking for null values

# %%
data.isna().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# ##### Checking the datatypes of columns

# %%
data.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# #### Let's see how data is distributed for each column

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for column in data:
    if plotnumber<=17:
        ax=plt.subplot(5,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# The is looking good let's move ahead

# %% [markdown]
# ### Checking outliers using boxplot

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for column in data:
    if plotnumber<=20:
        ax=plt.subplot(5,4,plotnumber)
        sns.boxplot(data=data[column],orient='v')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# We are not removing the errors since the columns in which ouliers present are possible oucomes

# %% [markdown]
# ### Checking correlation

# %%
data.corr()['W']
# Out:
# W      1.000000
# R      0.430751
# AB    -0.087947
# H      0.037612
# 2B     0.427797
# 3B    -0.251118
# HR     0.307407
# BB     0.484342
# SO     0.111850
# SB    -0.157234
# RA    -0.812952
# ER    -0.809435
# ERA   -0.819600
# CG     0.080533
# SHO    0.471805
# SV     0.666530
# E     -0.089485
# Name: W, dtype: float64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [markdown]
# #### Checking the columns which are positively and negatively correlated with the target variable

# %%
plt.figure(figsize=(22,7))
data.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar')
plt.xlabel('features',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# we are removing columns as they have very less relation with target variable

# %%
data_new=data.drop(columns=['E','CG','H','AB'])

# %%
data_new
# Out:
#       W    R   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV
# 0    95  724  300  42  139  383   973  104  641  601  3.73    8  56
# 1    83  696  277  44  156  439  1264   70  700  653  4.07   12  45
# 2    81  669  303  29  141  533  1157   86  640  584  3.67   10  38
# 3    76  622  260  27  136  404  1231   68  701  643  3.98    9  37
# 4    74  689  289  49  151  455  1259   83  803  746  4.64   12  35
# 5    93  891  308  17  232  570  1151   88  670  609  3.80   10  34
# 6    87  764  272  19  212  554  1227   63  698  652  4.03    4  48
# 7    81  713  246  20  217  418  1331   44  693  646  4.05   10  43
# 8    80  644  278  32  167  436  1310   87  642  604  3.74   12  60
# 9    78  748  294  33  161  478  1148   71  753  694  4.31   10  40
# 10   88  751  279  32  172  503  1233  101  733  680  4.24    9  45
# 11   86  729  278  26  230  486  1392  121  618  572  3.57   13  39
# 12   85  661  243  21  176  435  1150   52  675  630  3.94   12  46
# 13   76  656  262  22  198  478  1336   69  726  677  4.16   12  45
# 14   68  694  277  46  146  475  1119   78  729  664  4.14   15  28
# 15  100  647  288  39  137  506  1267   69  525  478  2.94   15  62
# 16   98  697  292  27  140  461  1322   98  596  532  3.21   13  54
# 17   97  689  272  30  171  567  1518   95  608  546  3.36   21  48
# 18   68  655  274  34  145  412  1299   84  737  682  4.28    7  40
# 19   64  640  257  27  167  496  1255  134  754  700  4.33    8  35
# 20   90  683  295  17  177  488  1290   51  613  557  3.43   14  50
# 21   83  703  265  13  177  539  1344   57  635  577  3.62   13  41
# 22   71  613  236  40  120  375  1150  112  678  638  4.02   12  35
# 23   67  573  251  18  100  471  1107   69  760  698  4.41   10  44
# 24   63  626  272  37  130  387  1274   88  809  749  4.69    7  35
# 25   92  667  263  26  187  563  1258   59  595  553  3.44   21  47
# 26   84  696  288  39  136  457  1159   93  627  597  3.72   18  41
# 27   79  720  289  48  154  490  1312  132  713  659  4.04   12  44
# 28   74  650  260  36  148  426  1327   82  731  655  4.09    6  41
# 29   68  737  274  49  186  388  1283   97  844  799  5.04    4  36

# %% [markdown]
# #### Dividing the dataset into Dependent and independent variables

# %%
x=data_new.drop(columns=['W'])
y=data_new['W']

# %%
x
# Out:
#       R   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV
# 0   724  300  42  139  383   973  104  641  601  3.73    8  56
# 1   696  277  44  156  439  1264   70  700  653  4.07   12  45
# 2   669  303  29  141  533  1157   86  640  584  3.67   10  38
# 3   622  260  27  136  404  1231   68  701  643  3.98    9  37
# 4   689  289  49  151  455  1259   83  803  746  4.64   12  35
# 5   891  308  17  232  570  1151   88  670  609  3.80   10  34
# 6   764  272  19  212  554  1227   63  698  652  4.03    4  48
# 7   713  246  20  217  418  1331   44  693  646  4.05   10  43
# 8   644  278  32  167  436  1310   87  642  604  3.74   12  60
# 9   748  294  33  161  478  1148   71  753  694  4.31   10  40
# 10  751  279  32  172  503  1233  101  733  680  4.24    9  45
# 11  729  278  26  230  486  1392  121  618  572  3.57   13  39
# 12  661  243  21  176  435  1150   52  675  630  3.94   12  46
# 13  656  262  22  198  478  1336   69  726  677  4.16   12  45
# 14  694  277  46  146  475  1119   78  729  664  4.14   15  28
# 15  647  288  39  137  506  1267   69  525  478  2.94   15  62
# 16  697  292  27  140  461  1322   98  596  532  3.21   13  54
# 17  689  272  30  171  567  1518   95  608  546  3.36   21  48
# 18  655  274  34  145  412  1299   84  737  682  4.28    7  40
# 19  640  257  27  167  496  1255  134  754  700  4.33    8  35
# 20  683  295  17  177  488  1290   51  613  557  3.43   14  50
# 21  703  265  13  177  539  1344   57  635  577  3.62   13  41
# 22  613  236  40  120  375  1150  112  678  638  4.02   12  35
# 23  573  251  18  100  471  1107   69  760  698  4.41   10  44
# 24  626  272  37  130  387  1274   88  809  749  4.69    7  35
# 25  667  263  26  187  563  1258   59  595  553  3.44   21  47
# 26  696  288  39  136  457  1159   93  627  597  3.72   18  41
# 27  720  289  48  154  490  1312  132  713  659  4.04   12  44
# 28  650  260  36  148  426  1327   82  731  655  4.09    6  41
# 29  737  274  49  186  388  1283   97  844  799  5.04    4  36

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# #### Checking skewness

# %%
x.skew()
# Out:
# R      1.200786
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# SHO    0.565790
# SV     0.657524
# dtype: float64

# %% [markdown]
# #### Removing skewness using power transform

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)

# %% [markdown]
# #### Scaling the data

# %%
sc=StandardScaler()
x_new=sc.fit_transform(x_new)

# %% [markdown]
# ### Checking Multicolinearity using VIF(variance inflation factor)

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_new,i)for i in range(x_new.shape[1])]
vif['features']=x.columns
vif
# Out:
#            vif features
# 0          NaN        R
# 1     2.011627       2B
# 2     2.687832       3B
# 3     2.845587       HR
# 4     2.553122       BB
# 5     2.309094       SO
# 6     1.869876       SB
# 7   143.057001       RA
# 8   541.359887       ER
# 9   293.270119      ERA
# 10    3.119315      SHO
# 11    3.141693       SV

# %% [markdown]
# There are 3 columns which are highly correlated so we can remove columns which have less vif value

# %%
x=x.drop(columns=['RA','ERA'])

# %%
x
# Out:
#       R   2B  3B   HR   BB    SO   SB   ER  SHO  SV
# 0   724  300  42  139  383   973  104  601    8  56
# 1   696  277  44  156  439  1264   70  653   12  45
# 2   669  303  29  141  533  1157   86  584   10  38
# 3   622  260  27  136  404  1231   68  643    9  37
# 4   689  289  49  151  455  1259   83  746   12  35
# 5   891  308  17  232  570  1151   88  609   10  34
# 6   764  272  19  212  554  1227   63  652    4  48
# 7   713  246  20  217  418  1331   44  646   10  43
# 8   644  278  32  167  436  1310   87  604   12  60
# 9   748  294  33  161  478  1148   71  694   10  40
# 10  751  279  32  172  503  1233  101  680    9  45
# 11  729  278  26  230  486  1392  121  572   13  39
# 12  661  243  21  176  435  1150   52  630   12  46
# 13  656  262  22  198  478  1336   69  677   12  45
# 14  694  277  46  146  475  1119   78  664   15  28
# 15  647  288  39  137  506  1267   69  478   15  62
# 16  697  292  27  140  461  1322   98  532   13  54
# 17  689  272  30  171  567  1518   95  546   21  48
# 18  655  274  34  145  412  1299   84  682    7  40
# 19  640  257  27  167  496  1255  134  700    8  35
# 20  683  295  17  177  488  1290   51  557   14  50
# 21  703  265  13  177  539  1344   57  577   13  41
# 22  613  236  40  120  375  1150  112  638   12  35
# 23  573  251  18  100  471  1107   69  698   10  44
# 24  626  272  37  130  387  1274   88  749    7  35
# 25  667  263  26  187  563  1258   59  553   21  47
# 26  696  288  39  136  457  1159   93  597   18  41
# 27  720  289  48  154  490  1312  132  659   12  44
# 28  650  260  36  148  426  1327   82  655    6  41
# 29  737  274  49  186  388  1283   97  799    4  36

# %% [markdown]
# ### Again checking the skewness After removing the multicollinearity

# %%
x.skew()
# Out:
# R      1.200786
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# ER     0.058710
# SHO    0.565790
# SV     0.657524
# dtype: float64

# %% [markdown]
# #### Again transforming the data

# %%
x_new=power_transform(x)

# %% [markdown]
# #### Scaling the data

# %%
x_new=sc.fit_transform(x_new)

# %% [markdown]
# #### Checking the multicollinearity again

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_new,i)for i in range(x_new.shape[1])]
vif['features']=x.columns
vif
# Out:
#         vif features
# 0       NaN        R
# 1  1.758574       2B
# 2  2.584569       3B
# 3  1.648810       HR
# 4  2.328289       BB
# 5  1.495913       SO
# 6  1.570483       SB
# 7  3.376214       ER
# 8  2.444019      SHO
# 9  1.760053       SV

# %% [markdown]
# Now all the VIF values are less than 5 , so we can proceed further

# %% [markdown]
# ### Finding the best random state

# %%
from sklearn.metrics import r2_score
LR=LinearRegression()

# %%
maxAccu=0
maxRS=0
for i in range(0,10000):
    x_train,x_test,y_train,y_test=train_test_split(x_new,y,test_size=0.20,random_state=i)
    LR.fit(x_train,y_train)
    y_pred=LR.predict(x_test)
    accu=r2_score(y_test,y_pred)
    if accu>maxAccu:
        maxAccu=accu
        maxRs=i
print('Max accuracy is ',maxAccu,'on random state',maxRs)
# Out:
# Max accuracy is  0.9843556240787904 on random state 3451

# %% [markdown]
# ### Splitting data Into Training and test data

# %%
x_train,x_test,y_train,y_test=train_test_split(x_new,y,test_size=0.20,random_state=3451)

# %%
LR.fit(x_train,y_train)
y_pred=LR.predict(x_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.9843556240787904

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(LR,x_new,y,cv=4)
print(cv_score.mean())
# Out:
# 0.6581387531534976

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Wins',fontsize=14)
plt.ylabel('Predicted Wins',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# ### Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# ### Lasso Regression

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10)),'max_iter':[100,200,500,1000],'normalize':[True,False]}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'max_iter': 100, 'normalize': True, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1,random_state=0,max_iter=100,normalize=True)
ls.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1, max_iter=100, normalize=True, random_state=0)

# %%
ls_pred=ls.predict(x_test)
lss=r2_score(y_test,ls_pred)
lss
# Out:
# 0.9376291264015558

# %%
cv_score_Lasso=cross_val_score(ls,x_new,y,cv=4)
print(cv_score_Lasso.mean())
# Out:
# 0.6301050256439129

# %% [markdown]
# ### Ridge Regression

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10)),'max_iter':[100,200,500,1000],'normalize':[True,False]}
Rg=Ridge()
clf=GridSearchCV(Rg,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'max_iter': 100, 'normalize': False, 'random_state': 0}

# %%
Rgg=Ridge(alpha=1,random_state=0,max_iter=100,normalize=False)
Rgg.fit(x_train,y_train)
# Out:
# Ridge(alpha=1, max_iter=100, random_state=0)

# %%
Rg_pred=Rgg.predict(x_test)
Rgs=r2_score(y_test,Rg_pred)
Rgs
# Out:
# 0.9902715100375142

# %%
cv_score_ridge=cross_val_score(Rgg,x_new,y,cv=4)
print(cv_score_ridge.mean())
# Out:
# 0.6548747190455715

# %% [markdown]
# ### Ensemble Technique

# %%
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %%
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(criterion='mae')

# %%
rf_pred=rf.predict(x_test)
rfs=r2_score(y_test,rf_pred)
rfs
# Out:
# 0.9044397163120568

# %%
cv_score_RF=cross_val_score(rf,x_new,y,cv=4)
print(cv_score_RF.mean())
# Out:
# 0.35201464367009094

# %% [markdown]
# So the best Accuracy is given by Ridge Regression so we will chose Ridge Regression as the best Model Algorithm

# %% [markdown]
# ### Saving the model

# %%
import pickle

# %%
filename='baseball.pkl'
pickle.dump(Rgg,open(filename,'wb'))

# %% [markdown]
# # Documentation

# %%
Import the csv file then seen the data,we describe the data and check the shape of the dataset. 
Then the vizualization of the  dataset is done and it seems fine.
After we check for the outliers using boxplot and we found outliers in some columns but we didn't remove them since they are possible outcomes.
After that we checked correlation with the target variable and remove columns ['E','CG','H','AB'] since they have very less relation with the target variable.
After that we devide the dataset into Dependent and independent variables.
After that we checked for thr skewness and found some skewness and we removed it with the help of power transform function.
After that we checked for multicollinearity and it is not found between the columns.
After that we trained the model with the several algorithms and found Ridge Regression as the best algo for our model.
Atre that we saved the model.
